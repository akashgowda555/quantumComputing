# %% [markdown]
# The following notebook demostrates svc using QSVM and quantum kernel.

# %%
from qiskit.utils import algorithm_globals
import random 
import numpy as np
from qiskit_machine_learning.datasets import ad_hoc_data
from qiskit.circuit.library import ZZFeatureMap, PauliFeatureMap
from qiskit.primitives import Sampler
from qiskit import *
from qiskit.algorithms.state_fidelities import ComputeUncompute
from qiskit_machine_learning.kernels import FidelityQuantumKernel, QuantumKernel
from qiskit_machine_learning.algorithms.classifiers import QSVC
from functools import reduce
import matplotlib.pyplot as plt

algorithm_globals.random_seed = 1222
adhoc_dimension = 2

def plotDatasetCircles(no_of_circles: int, no_of_points: int):
    points = []
    labels = []
    test_points = []
    test_labels = []
    center = 0
    radius = 0
    
    for i in range(no_of_circles):
        radius += random.uniform(1,100)
        for j in range(int(no_of_points*0.8)):
            theta = random.uniform(0, 360)
            points.append([center+radius*np.cos(theta), center+radius*np.sin(theta)])
            labels.append(i)
        for j in range(int(no_of_points*0.2)):
            theta = random.uniform(0, 360)
            test_points.append([center+radius*np.cos(theta), center+radius*np.sin(theta)])
            test_labels.append(i)            

    return np.array(points), np.array(labels),  np.array(test_points), np.array(test_labels)

data, labels, testd, testl = plotDatasetCircles(2, 40)
# Out:
# /tmp/ipykernel_212640/1554216149.py:8: DeprecationWarning: ``qiskit.algorithms`` has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. The ``qiskit.algorithms`` import path is deprecated as of qiskit-terra 0.25.0 and will be removed no earlier than 3 months after the release date. Please run ``pip install qiskit_algorithms`` and use ``import qiskit_algorithms`` instead.
#   from qiskit.algorithms.state_fidelities import ComputeUncompute

# %%
def plot_features(ax, features, labels, class_label, marker, face, edge, label):
    ax.scatter(
        features[np.where(labels[:] == class_label), 0],
        features[np.where(labels[:] == class_label), 1],
        marker=marker,
        facecolors=face,
        edgecolors=edge,
        label=label,
    )

def plot_dataset(train_features, train_labels, test_feature, test_label, adhoc_total):
    plt.figure(figsize=(5, 5))

    plot_features(plt, train_features, train_labels, 0, "s", "w", "b", "A train")
    plot_features(plt, train_features, train_labels, 1, "o", "w", "r", "B train")
    plot_features(plt, test_feature, test_label, 0, "s", "b", "w", "A test")
    plot_features(plt, test_feature, test_label, 1, "o", "r", "w", "A test")

    plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
    plt.title("Ad hoc dataset")

    plt.show()

# %%
plot_dataset(data, labels, testd, testl, len(data))

# %%
from qiskit.circuit import Parameter,ControlledGate
 
QC = QuantumCircuit(1)

theta1 = Parameter('theta1')
theta2 = Parameter('theta2')

QC.h(0)
QC.barrier()

QC.ry(theta1*theta1+theta2*theta2, 0)

QC.draw(output="mpl")

# %%
# %pip install qiskit_ibm_provider
# %pip install qiskit_ibm_runtime
from qiskit_ibm_provider import IBMProvider
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import Sampler
IBMProvider.save_account(token="eec157c47e5edfc746bac7681c227bd00c63e61766fbaef25551b8815783f8a42bf107db91d83edb564591a646971bf6c5023684ff9c381293f39b8cf51d3fbd", overwrite=True)
provider = IBMProvider()
service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.backend("ibm_perth")
# Out:
# Requirement already satisfied: qiskit_ibm_provider in /home/nagravision/intd/3.10/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: qiskit>=0.44.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (0.44.1)
# Requirement already satisfied: requests>=2.19 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (1.2.0)
# Requirement already satisfied: numpy>=1.13 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (1.25.2)
# Requirement already satisfied: urllib3>=1.21.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (1.26.16)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (1.6.1)
# Requirement already satisfied: websockets>=10.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (11.0.3)
# Requirement already satisfied: typing-extensions>=4.3 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_provider) (4.7.1)
# Requirement already satisfied: six>=1.5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit_ibm_provider) (1.16.0)
# Requirement already satisfied: qiskit-terra==0.25.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit>=0.44.1->qiskit_ibm_provider) (0.25.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (0.13.1)
# Requirement already satisfied: ply>=3.10 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (3.11)
# Requirement already satisfied: psutil>=5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (5.9.5)
# Requirement already satisfied: scipy>=1.5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (1.11.1)
# Requirement already satisfied: sympy>=1.3 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (1.12)
# Requirement already satisfied: dill>=0.3 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (0.9.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests>=2.19->qiskit_ibm_provider) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests>=2.19->qiskit_ibm_provider) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests>=2.19->qiskit_ibm_provider) (2023.7.22)
# Requirement already satisfied: cryptography>=1.3 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (41.0.3)
# Requirement already satisfied: pyspnego>=0.1.6 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (0.9.2)
# Requirement already satisfied: cffi>=1.12 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (1.15.1)
# Requirement already satisfied: pycparser in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (2.21)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_provider) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit_ibm_runtime in /home/nagravision/intd/3.10/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: qiskit>=0.44.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (0.44.1)
# Requirement already satisfied: requests>=2.19 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (1.2.0)
# Requirement already satisfied: numpy>=1.13 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (1.25.2)
# Requirement already satisfied: urllib3>=1.21.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (1.26.16)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (1.6.1)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (0.40.1)
# Requirement already satisfied: qiskit-ibm-provider>=0.7.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit_ibm_runtime) (0.7.0)
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.16.7 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (3.16.7)
# Requirement already satisfied: six>=1.5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit_ibm_runtime) (1.16.0)
# Requirement already satisfied: qiskit-terra==0.25.1 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit>=0.44.1->qiskit_ibm_runtime) (0.25.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (0.13.1)
# Requirement already satisfied: ply>=3.10 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (3.11)
# Requirement already satisfied: psutil>=5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (5.9.5)
# Requirement already satisfied: scipy>=1.5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (1.11.1)
# Requirement already satisfied: sympy>=1.3 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (1.12)
# Requirement already satisfied: dill>=0.3 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (0.9.2)
# Requirement already satisfied: typing-extensions in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (4.7.1)
# Requirement already satisfied: websockets>=10.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from qiskit-ibm-provider>=0.7.0->qiskit_ibm_runtime) (11.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests>=2.19->qiskit_ibm_runtime) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests>=2.19->qiskit_ibm_runtime) (2023.7.22)
# Requirement already satisfied: cryptography>=1.3 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (41.0.3)
# Requirement already satisfied: pyspnego>=0.1.6 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (0.9.2)
# Requirement already satisfied: cffi>=1.12 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (1.15.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.16.7->ibm-platform-services>=0.22.6->qiskit_ibm_runtime) (2.8.0)
# Requirement already satisfied: pycparser in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.21)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /home/nagravision/intd/3.10/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra==0.25.1->qiskit>=0.44.1->qiskit_ibm_runtime) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
sampler = Sampler(backend=backend)
fidelity = ComputeUncompute(sampler=sampler)
adhoc_kernel = FidelityQuantumKernel(fidelity=fidelity, feature_map=QC)

# %%
data, labels, testd, testl = plotDatasetCircles(2, 20)
plot_dataset(data, labels, testd, testl, len(data))

# %%
qsvc = QSVC(quantum_kernel=adhoc_kernel)
qsvc.fit(data, labels)

adhoc_score_callable_function = qsvc.score(testd, testl)

print(f"Callable kernel classification test score: {adhoc_score_callable_function}")

# %%
print(f"Callable kernel classification test score: {adhoc_score_callable_function}")
# Out:
# Callable kernel classification test score: 1.0
